# %% [markdown]
# # ***Data preparation***
#
# *   Download dataset
# *   Label & Image extraction in ordered matrices of required size

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import glob  # finding image paths

# %%
from google.colab import drive
# mount drive to import dataset
drive.mount('/content/drive')

# %%
import numpy as np

# create an empty array of the desired shape and data type
train_images = np.empty([10, 1280, 720, 3], dtype=np.uint8)
# make some fake label values as an example
train_labels = np.arange(20)
# convert this 1D array to 2D array
train_labels = np.expand_dims(train_labels, axis=1)

img_name = sorted(glob.glob('/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/*.png'))

images_list = []
print(img_name)
#data_path = '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images'
#counter = 1
#plt.figure(figsize=(20,20))
for i in range(20):
  #img_name = data_path + "%02d" % i + '.png'
  #print(type(i))

  #train_images[i, :, :, :] = plt.imread(img_name[i])
  images_list.append(plt.imread(img_name[i]))
  #counter = counter +1

  #print(type(plt.imread(img_name[i])))

# test images
test_images = train_images.copy()  
test_labels = train_labels.copy()
# Out:
# ['/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1.png', '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1021.png', '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1051.png', '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1081.png', '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1111.png', '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1141.png', '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1171.png', '/content/drive/Shareddrives/Machine_Vision_Group_4/MinneApple_Datasets/Smaller_Dataset/images/dataset1_back_1201.png', '/content/drive/Shareddrives/Machine_Vis
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.figure(figsize=(20,20))
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    #plt.imshow(train_images[i, :, :, :], cmap=plt.cm.binary)
    plt.imshow(images_list[i])
    plt.xlabel(train_labels[i][0])
plt.show()
